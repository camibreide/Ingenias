# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp
import seaborn as sb

# %%
df=pd.read_csv(r"C:/Users/Lenovo/Downloads/archive/Sleep_health_and_lifestyle_dataset.csv")
df.head(10)
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 5          6   Male   28     Software Engineer             5.9
# 6          7   Male   29               Teacher             6.3
# 7          8   Male   29                Doctor             7.8
# 8          9   Male   29                Doctor             7.8
# 9         10   Male   29                Doctor             7.8
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# ...

# %%
df.size
# Out:
# 4862

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
pd.unique(df["Quality of Sleep"])
# Out:
# array([6, 4, 7, 5, 8, 9], dtype=int64)

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# dtype: object

# %%
mp.figure()
sb.scatterplot(x="Quality of Sleep", y="Sleep Duration",data=df, palette="spring")
sb.despine()
mp.show();
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8356\2661124480.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sb.scatterplot(x="Quality of Sleep", y="Sleep Duration",data=df, palette="spring")

# %%
mp.figure()
sb.scatterplot(x="Quality of Sleep", y="Sleep Duration",data=df, palette="spring")
sb.despine()
mp.show();

# %%
df.isna().any()
# Out:
# Person ID                  False
# Gender                     False
# Age                        False
# Occupation                 False
# Sleep Duration             False
# Quality of Sleep           False
# Physical Activity Level    False
# Stress Level               False
# BMI Category               False
# Blood Pressure             False
# Heart Rate                 False
# Daily Steps                False
# Sleep Disorder              True
# dtype: bool

# %%
df.isnull().any()
#Hay valores faltantes en Sleep Disorder
# Out:
# Person ID                  False
# Gender                     False
# Age                        False
# Occupation                 False
# Sleep Duration             False
# Quality of Sleep           False
# Physical Activity Level    False
# Stress Level               False
# BMI Category               False
# Blood Pressure             False
# Heart Rate                 False
# Daily Steps                False
# Sleep Disorder              True
# dtype: bool

# %%
pd.unique(df["Gender"])
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.groupby(by="Gender").count()
#Hay cantidades similares de registros Femeninos y masculinos, pero en la columna Slep Disorder hay menor cantidad de registros ademas de disparidad, tenemos mas info de mujeres que de hombres: Es un error o los hombres tienen menos Desordenes del Sueño?
# Out:
#         Person ID  Age  Occupation  Sleep Duration  Quality of Sleep  \
# Gender
# Female        185  185         185             185               185
# Male          189  189         189             189               189
#
#         Physical Activity Level  Stress Level  BMI Category  Blood Pressure  \
# Gender
# Female                      185           185           185             185
# Male                        189           189           189             189
#
#         Heart Rate  Daily Steps  Sleep Disorder
# Gender
# Female         185          185             103
# Male           189          189              52

# %%
df.groupby(by="Occupation").count()
# Out:
#                       Person ID  Gender  Age  Sleep Duration  \
# Occupation
# Accountant                   37      37   37              37
# Doctor                       71      71   71              71
# Engineer                     63      63   63              63
# Lawyer                       47      47   47              47
# Manager                       1       1    1               1
# Nurse                        73      73   73              73
# Sales Representative          2       2    2               2
# Salesperson                  32      32   32              32
# Scientist                     4       4    4               4
# Software Engineer             4       4    4               4
# Teacher                      40      40   40              40
#
#                       Quality of Sleep  Physical Activity Level  Stress Level  \
# Occupation
# Accountant                          37                       37            37
# ...

# %%
df.groupby(by="Age").count()
# Out:
#      Person ID  Gender  Occupation  Sleep Duration  Quality of Sleep  \
# Age
# 27           1       1           1               1                 1
# 28           5       5           5               5                 5
# 29          13      13          13              13                13
# 30          13      13          13              13                13
# 31          18      18          18              18                18
# 32          17      17          17              17                17
# 33          13      13          13              13                13
# 34           2       2           2               2                 2
# 35          12      12          12              12                12
# 36          12      12          12              12                12
# 37          20      20          20              20                20
# 38          20      20          20              20                20
# ...

# %%
df.groupby(by="Sleep Disorder").count()
# Out:
#                 Person ID  Gender  Age  Occupation  Sleep Duration  \
# Sleep Disorder
# Insomnia               77      77   77          77              77
# Sleep Apnea            78      78   78          78              78
#
#                 Quality of Sleep  Physical Activity Level  Stress Level  \
# Sleep Disorder
# Insomnia                      77                       77            77
# Sleep Apnea                   78                       78            78
#
#                 BMI Category  Blood Pressure  Heart Rate  Daily Steps
# Sleep Disorder
# Insomnia                  77              77          77           77
# Sleep Apnea               78              78          78           78

# %%
#Ver gráficamente cantidad de personas con cada tipo de desorden, según su género
mp.figure()
sb.histplot(data=df, x="Sleep Disorder", hue="Gender", multiple="stack")
mp.show();
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
